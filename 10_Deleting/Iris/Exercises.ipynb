# %% [markdown]
# # Iris

# %% [markdown]
# ### Introduction:
#
# This exercise may seem a little bit strange, but keep doing it.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called iris

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris = pd.read_csv(url)
iris.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %% [markdown]
# ### Step 4. Create columns for the dataset

# %%
# 1. sepal_length (in cm)
# 2. sepal_width (in cm)
# 3. petal_length (in cm)
# 4. petal_width (in cm)
# 5. class
iris_columns = ["sepal_length (in cm)",
                "sepal_width (in cm)",
                "petal_length (in cm)",
                "petal_width (in cm)",
                "class"]
iris.columns = iris_columns
iris.head()
# Out:
#    sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                   4.9                  3.0                   1.4
# 1                   4.7                  3.2                   1.3
# 2                   4.6                  3.1                   1.5
# 3                   5.0                  3.6                   1.4
# 4                   5.4                  3.9                   1.7
#
#    petal_width (in cm)        class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.4  Iris-setosa

# %% [markdown]
# ### Step 5.  Is there any missing value in the dataframe?

# %%
iris.isna().sum()
# No missing values.
# Out:
# sepal_length (in cm)    0
# sepal_width (in cm)     0
# petal_length (in cm)    0
# petal_width (in cm)     0
# class                   0
# dtype: int64

# %% [markdown]
# ### Step 6.  Lets set the values of the rows 10 to 29 of the column 'petal_length' to NaN

# %%
iris.iloc[10:30,2] = np.nan
iris.head(32)
# Out:
#     sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                    4.9                  3.0                   1.4
# 1                    4.7                  3.2                   1.3
# 2                    4.6                  3.1                   1.5
# 3                    5.0                  3.6                   1.4
# 4                    5.4                  3.9                   1.7
# 5                    4.6                  3.4                   1.4
# 6                    5.0                  3.4                   1.5
# 7                    4.4                  2.9                   1.4
# 8                    4.9                  3.1                   1.5
# 9                    5.4                  3.7                   1.5
# 10                   4.8                  3.4                   NaN
# 11                   4.8                  3.0                   NaN
# 12                   4.3                  3.0                   NaN
# 13                   5.8                  4.0                   NaN
# 14                   5.7                  4.4                   NaN
# 15                   5.4                  3.9                   NaN
# 16                   5.1                  3.5                   NaN
# 17                   5.7                  3.8                   NaN
# 18                   5.1                  3.8                   NaN
# 19                   5.4                  3.4                   NaN
# 20                   5.1                  3.7                   NaN
# 21                   4.6                  3.6                   NaN
# 22                   5.1                  3.3                   NaN
# 23                   4.8                  3.4                   NaN
# 24                   5.0                  3.0                   NaN
# 25                   5.0                  3.4                   NaN
# 26                   5.2                  3.5                   NaN
# 27                   5.2                  3.4                   NaN
# 28                   4.7                  3.2                   NaN
# 29                   4.8                  3.1                   NaN
# 30                   5.4                  3.4                   1.5
# 31                   5.2                  4.1                   1.5
#
#     petal_width (in cm)        class
# 0                   0.2  Iris-setosa
# 1                   0.2  Iris-setosa
# 2                   0.2  Iris-setosa
# 3                   0.2  Iris-setosa
# 4                   0.4  Iris-setosa
# 5                   0.3  Iris-setosa
# 6                   0.2  Iris-setosa
# 7                   0.2  Iris-setosa
# 8                   0.1  Iris-setosa
# 9                   0.2  Iris-setosa
# 10                  0.2  Iris-setosa
# 11                  0.1  Iris-setosa
# 12                  0.1  Iris-setosa
# 13                  0.2  Iris-setosa
# 14                  0.4  Iris-setosa
# 15                  0.4  Iris-setosa
# 16                  0.3  Iris-setosa
# 17                  0.3  Iris-setosa
# 18                  0.3  Iris-setosa
# 19                  0.2  Iris-setosa
# 20                  0.4  Iris-setosa
# 21                  0.2  Iris-setosa
# 22                  0.5  Iris-setosa
# 23                  0.2  Iris-setosa
# 24                  0.2  Iris-setosa
# 25                  0.4  Iris-setosa
# 26                  0.2  Iris-setosa
# 27                  0.2  Iris-setosa
# 28                  0.2  Iris-setosa
# 29                  0.2  Iris-setosa
# 30                  0.4  Iris-setosa
# 31                  0.1  Iris-setosa

# %% [markdown]
# ### Step 7. Good, now lets substitute the NaN values to 1.0

# %%
iris['petal_length (in cm)'][iris['petal_length (in cm)'].isna()] = 1.0
# iris.petal_length.fillna(1, inplace = True)

iris.head(35)
# Out:
# C:\Users\utsav\anaconda3\envs\DataAnalytics\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                    4.9                  3.0                   1.4
# 1                    4.7                  3.2                   1.3
# 2                    4.6                  3.1                   1.5
# 3                    5.0                  3.6                   1.4
# 4                    5.4                  3.9                   1.7
# 5                    4.6                  3.4                   1.4
# 6                    5.0                  3.4                   1.5
# 7                    4.4                  2.9                   1.4
# 8                    4.9                  3.1                   1.5
# 9                    5.4                  3.7                   1.5
# 10                   4.8                  3.4                   1.0
# 11                   4.8                  3.0                   1.0
# 12                   4.3                  3.0                   1.0
# 13                   5.8                  4.0                   1.0
# 14                   5.7                  4.4                   1.0
# 15                   5.4                  3.9                   1.0
# 16                   5.1                  3.5                   1.0
# 17                   5.7                  3.8                   1.0
# 18                   5.1                  3.8                   1.0
# 19                   5.4                  3.4                   1.0
# 20                   5.1                  3.7                   1.0
# 21                   4.6                  3.6                   1.0
# 22                   5.1                  3.3                   1.0
# 23                   4.8                  3.4                   1.0
# 24                   5.0                  3.0                   1.0
# 25                   5.0                  3.4                   1.0
# 26                   5.2                  3.5                   1.0
# 27                   5.2                  3.4                   1.0
# 28                   4.7                  3.2                   1.0
# 29                   4.8                  3.1                   1.0
# 30                   5.4                  3.4                   1.5
# 31                   5.2                  4.1                   1.5
# 32                   5.5                  4.2                   1.4
# 33                   4.9                  3.1                   1.5
# 34                   5.0                  3.2                   1.2
#
#     petal_width (in cm)        class
# 0                   0.2  Iris-setosa
# 1                   0.2  Iris-setosa
# 2                   0.2  Iris-setosa
# 3                   0.2  Iris-setosa
# 4                   0.4  Iris-setosa
# 5                   0.3  Iris-setosa
# 6                   0.2  Iris-setosa
# 7                   0.2  Iris-setosa
# 8                   0.1  Iris-setosa
# 9                   0.2  Iris-setosa
# 10                  0.2  Iris-setosa
# 11                  0.1  Iris-setosa
# 12                  0.1  Iris-setosa
# 13                  0.2  Iris-setosa
# 14                  0.4  Iris-setosa
# 15                  0.4  Iris-setosa
# 16                  0.3  Iris-setosa
# 17                  0.3  Iris-setosa
# 18                  0.3  Iris-setosa
# 19                  0.2  Iris-setosa
# 20                  0.4  Iris-setosa
# 21                  0.2  Iris-setosa
# 22                  0.5  Iris-setosa
# 23                  0.2  Iris-setosa
# 24                  0.2  Iris-setosa
# 25                  0.4  Iris-setosa
# 26                  0.2  Iris-setosa
# 27                  0.2  Iris-setosa
# 28                  0.2  Iris-setosa
# 29                  0.2  Iris-setosa
# 30                  0.4  Iris-setosa
# 31                  0.1  Iris-setosa
# 32                  0.2  Iris-setosa
# 33                  0.1  Iris-setosa
# 34                  0.2  Iris-setosa

# %% [markdown]
# ### Step 8. Now let's delete the column class

# %%
iris.drop(['class'], axis = 1, inplace = True)
iris.head()
# Out:
#    sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                   4.9                  3.0                   1.4
# 1                   4.7                  3.2                   1.3
# 2                   4.6                  3.1                   1.5
# 3                   5.0                  3.6                   1.4
# 4                   5.4                  3.9                   1.7
#
#    petal_width (in cm)
# 0                  0.2
# 1                  0.2
# 2                  0.2
# 3                  0.2
# 4                  0.4

# %% [markdown]
# ### Step 9.  Set the first 3 rows as NaN

# %%
iris.iloc[:3] = np.nan
iris.head()
# Out:
#    sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                   NaN                  NaN                   NaN
# 1                   NaN                  NaN                   NaN
# 2                   NaN                  NaN                   NaN
# 3                   5.0                  3.6                   1.4
# 4                   5.4                  3.9                   1.7
#
#    petal_width (in cm)
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  0.2
# 4                  0.4

# %% [markdown]
# ### Step 10.  Delete the rows that have NaN

# %%
iris.dropna(axis = 0, inplace = True)
iris.head()
# Out:
#    sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 3                   5.0                  3.6                   1.4
# 4                   5.4                  3.9                   1.7
# 5                   4.6                  3.4                   1.4
# 6                   5.0                  3.4                   1.5
# 7                   4.4                  2.9                   1.4
#
#    petal_width (in cm)
# 3                  0.2
# 4                  0.4
# 5                  0.3
# 6                  0.2
# 7                  0.2

# %% [markdown]
# ### Step 11. Reset the index so it begins with 0 again

# %%
iris.reset_index(inplace = True)
iris.head()
# Out:
#    index  sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0      3                   5.0                  3.6                   1.4
# 1      4                   5.4                  3.9                   1.7
# 2      5                   4.6                  3.4                   1.4
# 3      6                   5.0                  3.4                   1.5
# 4      7                   4.4                  2.9                   1.4
#
#    petal_width (in cm)
# 0                  0.2
# 1                  0.4
# 2                  0.3
# 3                  0.2
# 4                  0.2

# %% [markdown]
# ### BONUS: Create your own question and answer it.
